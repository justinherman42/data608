# %%
import sys,time,random
game_over = False
typing_speed = 50 #wpm
from os import system

### My Functions 

## What does Slow type do?(DELETE MY COMMENT AND ADD YOUR OWN)
def slow_type(t):
    for l in t:
        sys.stdout.write(l)
        sys.stdout.flush()
        time.sleep(random.random()*.1/typing_speed)
    print ('')

## What does Slower type do? give credit to stack user (DELETE MY COMMENT AND ADD YOUR OWN)
## 
## https://stackoverflow.com/questions/39422027/slow-printing-still-need-answers

def slower_type(t):
    for l in t:
        ## what does write do?
        sys.stdout.write(l)
        sys.stdout.flush()
        
        ## what is this doing?
        time.sleep(random.random()*.1/typing_speed)
    print ('')

## Build my porgram
def main():
    done = False
    while not done:
        print("Menu")
        print("G - Game")
        print("C - Clear Screen")
        print("Q - Quit")
        choice = input("Choice: ")
        if choice == "G":
            game()

        elif choice == "C":
            system('clear')

        elif choice == "Q":
            print("Exiting!")
            done = True
            
def game():


## set items and health- Are we using all of this?(DELETE MY COMMENT AND ADD YOUR OWN)
    items = ["sword(s) = $50","food packages(f) = $30","map(m) = $20"]
    money = 150
    enemyhealth = 2000
    userhealth = 100

    ## Ive added a random function that puts a random swords into backpack
    backpack = []
    bossreactions = ["OOF","That was nothing","Not bad","..."]
    swords = ["Heavy Sword, ","Light Sword "]

    print("Starting game...")
    print("Welcome")
    print("to")

    ## User enters name
    nog = input("What should the name of the character be called: ")

    ## Secret printouts if user enters correct secret name 
    if nog == "Beanos":
        slow_type("you drafted a theme from spongebob, nice")
    elif nog == "Shrek":
        slow_type("Shrek is love, Shrek is life")
        slow_type("( ͡° ͜ʖ °)")
    elif nog == "Waluigi":
        print(nog,"is not in smash")
    elif nog == "Shaggy":
        print(nog,"is in his final form")
    print("The Adventures of",nog)
    slow_type("Loading...")
    slow_type("....")
    slow_type("You start on a hilly mountain with a bunch of trees around you.")

    ## Ask user to move forward or back:
    move1 = input("What would you like to do next move(forward or backward): ")
    if move1 == "backward":

        ##storyline dialgoue
        slow_type("You start to walk toward the edge of the mountain and you realize you are standing on a cliff")
        slow_type("You decide to go to the left because")
        slow_type("You see a small building in the distance")
        slow_type("The building has a busted up sign on it that reads")
        slow_type("Free Stuff")

        ## ask user if he wants to go in to buy map
        building = input("Would you like to go inside the building(Y or N): ")
        if building == "N":
            print("")
        elif building == "Y":
            slow_type("You go inside of the building and see a shop clerk")
            slow_type("The shop clerk asks you")
            buym = input("Would you like to buy a map(Y or N): ")
            if buym == "Y":
                backpack.append("Map")
                items.remove("map(m) = $20")
                print(backpack)
                slow_type("You have a map")
                backpack.remove("Map")
            if buym == "N":
                print("")
        slow_type("You continue on your adventure")

    elif move1 == "forward":
        print("")

    ## user dies for not following directions
    else:
        slow_type("I told you to enter backward or forward, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()
    
    
    ##storyline dialgoue
    slow_type("You slide down the mountain and stumble upon a village")
    slow_type("You go to the village and see a ghost town that looks run down.")
    slow_type("As you start to walk toward the village")
    slow_type("A villager runs up to you and says")
    slow_type("Dont go there its too dangerous")
    slow_type("You continue on toward the village and see that every building is destroyed except for 1")
    slow_type("You walk up to the building and knock on the door.")
    slow_type("A villager come out and says")
    slow_type("Hurry come in, theyll get you")

    ## ask user to go inside. if he says no he dies
    insideb = input("Do you go inside yes or no: ")
    if insideb == "no":
        print("You start to walk back when you get struck in the head and sent to a river,you died")
        slower_type("Game over.....")
        sys.exit()

    elif insideb == "yes":
        ##storyline dialgoue
        slow_type("So you hurry on inside")
        slow_type("As soon as you went in, you realize that this building is a lot bigger on the inside than the outside")
        slow_type("The villager said")
        print("Hello",nog,"finally you have come to rescue us")
        print(nog,"says, how do you know my name, and what am reacuing you guys from?")
        slow_type("You are rescuing us from Franz Gigalance, you didn't know?")
        slow_type("He took our power gem and now the village is destroying itself.")
        slow_type("Ive heard that he is taking the gem to The Naguakate Volcano.")
        print(nog,"says")
        slow_type("How am I suposed to help, I dont even know where that is.")
        slow_type("I know you dont but I do, here let me show you")
        slow_type("🏠------------------🌊")
        slow_type("                    |")
        slow_type("                    |")
        slow_type("                    🌋")
        print(nog,",just follow the path and it shall take you there, goodluck")
        slow_type("You leave the building stealthy and quickly go strait.")
        slow_type("You realize that you dont have any gear with you.")

        ## ask user if he wants to go back, if yes he dies
        backg = input("Would you like to go back (Y or N): ")
        if backg == "Y":
            slow_type("You start to go back and notice something following you")
            slow_type("You try to continue back but your mauled by a bear ")
            slower_type("Game over.....")
            sys.exit()
        elif backg == "N":
            slow_type("You keep going on the path")
            slow_type("As you were walking you see a river")
            slow_type("By the river, you see a chest")

            ## ask user to open chest: He will be randomly assigned sword
            openchest = input("Would you like to open the chest(Y or N): ")
            if openchest == "Y":
                backpack.append(random.choice(swords))
                backpack.append("Food")
                slow_type("You have")
                slow_type(backpack)
            elif openchest == "N":
                slower_type("You will regret that...")

        ##storyline dialgoue
        slow_type("You continue on and see the enormous volcano in the distance.")
        slow_type("You can see small sparks coming from the volcano")
        slow_type("As you continue on you see a large bridge that is over a rapid river.")
        slower_type("...")
        slower_type("....")
        slow_type("..........................")
        print("( ͡°( ͡° ͜ʖ ͡°( ͡❛ ͜ʖ͡❛ ) ͡° ͜ʖ ͡°) ͡°)")
        print("Hello",nog)
        slow_type("Finally you have come")
        slow_type("Now we shall fight")
        slow_type("You stand no match for my men")

        ## build lists to determine if attack is superattack
        attack_list = ["Attack"] * 90
        sattack_list = ["Super Attack"] * 1
        sa_list = attack_list + sattack_list

        ## randomly pick attack/superattack
        if random.choice(sa_list).startswith("S"):
            smessage = True
        else:
            smessage = False

        ## h sword does more damage
        if "Heavy Sword, " in backpack:
            if random.choice(sa_list).startswith("S"):
                smessage = True
            dam = random.randint(65,75)
            print(dam)
            print("Heavy Sword, ")
        ## light sword does less
        elif "Light Sword " in backpack:
            dam = random.randint(35,55)
            print dam
            print("Light sword")
        else: print(" you have no sword to attack with")
        f = False
    
      ## user dies for not following directions
    else:
        slow_type("I told you to enter yes or no, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()
    
    ## boss battle: ends if boss or player health falls below 0
    while enemyhealth > 0:
        if random.choice(sa_list).startswith("S"):
            smessage = True
        if smessage == True:
            print("SA - Super Attack")
            print("H - Heal")
            ## made it so lower case dosen't insta kill
            u_input = input(":: ").upper()
            if u_input == "SA":
                print(random.choice(bossreactions))
                sdam = 2000
                strdam = str(sdam)
                enemyhealth -= sdam
                print(enemyhealth)
                slow_type("Damage drawn: "+ strdam)
                break
            elif u_input == "H":
                userhealth += 40
                print(userhealth)

        ## not super attack
        print("A - Attack")
        print("H - Heal")
        ## made it so lower case dosen't insta kill
        u_input = input(":: ").upper()
        if u_input == "A":
            print(random.choice(bossreactions))
            dam = random.randint(45,50)
            strdam = str(dam)
            enemyhealth -= dam
            print(enemyhealth)
            slow_type("Damage drawn: "+ strdam)
        elif u_input == "H":
            userhealth += 40
            print(userhealth)

        else:
            slower_type("So you have choosen death")
            slower_type("GAME OVER")
            break
        ## add instant death while not open chest
        if openchest == "N":
            slower_type("I warned you")
           ## loop will diminish users health untill 0
           ## sys is used to print users heath in the same place
            while userhealth > 0:
                userhealth -= 1
                struserhealth = str(userhealth)
                sys.stdout.write("User Health:" +struserhealth+   " \r")
                sys.stdout.flush()
                time.sleep(0.05)
            ## Because users health was printing in place I added User Heal to clean the wording up
            print("User Heal")
            slower_type("GAME OVER")
            break

        ## boss attacks, user takes damage
        bam = random.randint(30,45)
        strbam = str(bam)
        for x in range(1,bam + 1):
            userhealth -= 1
            sys.stdout.write("User Health:" +str(userhealth)+" " +  "\r")
            sys.stdout.flush()
            time.sleep(0.05)
            if userhealth <= 0:
                slower_type(" You Died......GAME OVER")
                game_over = True
                break
        ### add it here
        slow_type("\n Boss Damage drawn: "+ strbam)
        if userhealth <= 0:
            sys.exit()
        #    break
        #else: continue

main()

# %%
import sys,time,random
game_over = False
typing_speed = 50 #wpm
from os import system

## My Functions

## Slow type makes it so that when something is printed, it prints it out letter by letter
def slow_type(t):
    for l in t:
        sys.stdout.write(l)
        sys.stdout.flush()
        time.sleep(random.random()*5/typing_speed)
    print ('')

## Slower type makes it so that when something is printed, it prints it out letter by letter but even slower
##
## https://stackoverflow.com/questions/39422027/slow-printing-still-need-answers

def slower_type(t):
    for l in t:
        ## what does write do?
        sys.stdout.write(l)
        sys.stdout.flush()

        ## what is this doing?
        time.sleep(random.random()*20/typing_speed)
    print ('')

## Build my porgram
def main():
    done = False
    while not done:
        print("Menu")
        print("G - Game")
        print("C - Clear Screen")
        print("Q - Quit")
        choice = input("Choice: ")
        if choice == "G":
            game()

        elif choice == "C":
            system('clear')

        elif choice == "Q":
            print("Exiting!")
            done = True

def game():


## items are set to shwo what is going to be used in the story
## enemy health and user health are set to their variables
    items = ["sword(s) = $50","food packages(f) = $30","map(m) = $20"]
    enemyhealth = 2000
    userhealth = 100

    ## Ive added a random function that puts a random swords into backpack
    backpack = []
    bossreactions = ["OOF","That was nothing","Not bad","..."]
    swords = ["Heavy Sword, ","Light Sword "]

    print("Starting game...")
    print("Welcome")
    print("to")

    ## User enters name
    nog = input("What should the name of the character be called: ")

    ## Secret printouts if user enters correct secret name
    if nog == "Beanos":
        slow_type("you drafted a theme from spongebob, nice")
    elif nog == "Shrek":
        slow_type("Shrek is love, Shrek is life")
        slow_type("( ͡° ͜ʖ °)")
    elif nog == "Waluigi":
        print(nog,"is not in smash")
    elif nog == "Shaggy":
        print(nog,"is in his final form")
    print("The Adventures of",nog)
    slow_type("Loading...")
    slow_type("....")
    slow_type("You start on a hilly mountain with a bunch of trees around you.")

    ## Ask user to move forward or back:
    move1 = input("What would you like to do next move(forward or backward): ")
    if move1 == "backward":

        ##storyline dialgoue
        slow_type("You start to walk toward the edge of the mountain and you realize you are standing on a cliff")
        slow_type("You decide to go to the left because")
        slow_type("You see a small building in the distance")
        slow_type("The building has a busted up sign on it that reads")
        slow_type("Free Stuff")

        ## ask user if he wants to go in to buy map
        building = input("Would you like to go inside the building(Y or N): ")
        if building == "N":
            print("")
        elif building == "Y":
            slow_type("You go inside of the building and see a shop clerk")
            slow_type("The shop clerk asks you")
            buym = input("Would you like to buy a map(Y or N): ")
            if buym == "Y":
                backpack.append("Map")
                items.remove("map(m) = $20")
                print(backpack)
                slow_type("You have a map")
                backpack.remove("Map")
            if buym == "N":
                print("")
        slow_type("You continue on your adventure")

    elif move1 == "forward":
        print("")

    ## user dies for not following directions
    else:
        slow_type("I told you to enter backward or forward, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()


    ##storyline dialgoue
    slow_type("You slide down the mountain and stumble upon a village")
    slow_type("You go to the village and see a ghost town that looks run down.")
    slow_type("As you start to walk toward the village")
    slow_type("A villager runs up to you and says")
    slow_type("Dont go there its too dangerous")
    slow_type("You continue on toward the village and see that every building is destroyed except for 1")
    slow_type("You walk up to the building and knock on the door.")
    slow_type("A villager come out and says")
    slow_type("Hurry come in, theyll get you")

    ## ask user to go inside. if he says no he dies
    insideb = input("Do you go inside yes or no: ")
    if insideb == "no":
        print("You start to walk back when you get struck in the head and sent to a river,you died")
        slower_type("Game over.....")
        sys.exit()

    elif insideb == "yes":
        ##storyline dialgoue
        slow_type("So you hurry on inside")
        slow_type("As soon as you went in, you realize that this building is a lot bigger on the inside than the outside")
        slow_type("The villager said")
        print("Hello",nog,"finally you have come to rescue us")
        print(nog,"says, how do you know my name, and what am reacuing you guys from?")
        slow_type("You are rescuing us from Franz Gigalance, you didn't know?")
        slow_type("He took our power gem and now the village is destroying itself.")
        slow_type("Ive heard that he is taking the gem to The Naguakate Volcano.")
        print(nog,"says")
        slow_type("How am I suposed to help, I dont even know where that is.")
        slow_type("I know you dont but I do, here let me show you")
        slow_type("🏠------------------🌊")
        slow_type("                    |")
        slow_type("                    |")
        slow_type("                    🌋")
        print(nog,",just follow the path and it shall take you there, goodluck")
        slow_type("You leave the building stealthy and quickly go strait.")
        slow_type("You realize that you dont have any gear with you.")

        ## ask user if he wants to go back, if yes he dies
        backg = input("Would you like to go back (Y or N): ")
        if backg == "Y":
            slow_type("You start to go back and notice something following you")
            slow_type("You try to continue back but your mauled by a bear ")
            slower_type("Game over.....")
            sys.exit()
        elif backg == "N":
            slow_type("You keep going on the path")
            slow_type("As you were walking you see a river")
            slow_type("By the river, you see a chest")

            ## ask user to open chest: He will be randomly assigned sword
            openchest = input("Would you like to open the chest(Y or N): ")
            if openchest == "Y":
                backpack.append(random.choice(swords))
                backpack.append("Food")
                slow_type("You have")
                slow_type(backpack)
            elif openchest == "N":
                slower_type("You will regret that...")

        ##storyline dialgoue
        slow_type("You continue on and see the enormous volcano in the distance.")
        slow_type("You can see small sparks coming from the volcano")
        slow_type("As you continue on you see a large bridge that is over a rapid river.")
        slower_type("...")
        slower_type("....")
        slow_type("..........................")
        print("( ͡°( ͡° ͜ʖ ͡°( ͡❛ ͜ʖ͡❛ ) ͡° ͜ʖ ͡°) ͡°)")
        print("Hello",nog)
        slow_type("Finally you have come")
        slow_type("Now we shall fight")
        slow_type("You stand no match for my men")

        ## build lists to determine if attack is superattack
        attack_list = ["Attack"] * 90
        sattack_list = ["Super Attack"] * 1
        sa_list = attack_list + sattack_list

        ## randomly pick attack/superattack
        if random.choice(sa_list).startswith("S"):
            smessage = True
        else:
            smessage = False

        ## h sword does more damage
        if "Heavy Sword, " in backpack:
            if random.choice(sa_list).startswith("S"):
                smessage = True
            dam = random.randint(65,75)
            print(dam)
            print("from heavy sword")

        ## light sword does less
        elif "Light Sword " in backpack:
            dam = random.randint(35,55)
            print(dam)
            print("from light sword")
        else: print(" you have no sword to attack with")
        f = False

      ## user dies for not following directions
    else:
        slow_type("I told you to enter yes or no, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()

    ## boss battle: ends if boss or player health falls below 0
    while enemyhealth > 0:
        if random.choice(sa_list).startswith("S"):
            smessage = True
        if smessage == True:
            print("SA - Super Attack")
            print("H - Heal")
            ## made it so lower case dosen't insta kill
            u_input = input(":: ").upper()
            if u_input == "SA":
                print(random.choice(bossreactions))
                sdam = 2000
                strdam = str(sdam)
                enemyhealth -= sdam
                print(enemyhealth)
                slow_type("Damage drawn: "+ strdam)
                break
            elif u_input == "H":
                userhealth += 40
                print(userhealth)

        ## not super attack
        print("A - Attack")
        print("H - Heal")
        ## made it so lower case dosen't insta kill
        u_input = input(":: ").upper()
        if u_input == "A":
            print(random.choice(bossreactions))
            ################################################## HERE LOOK HERE
            dam = random.randint(45,50)
            strdam = str(dam)
            enemyhealth -= dam
            print(enemyhealth)
            slow_type("Damage drawn: "+ strdam)
        elif u_input == "H":
            userhealth += 40
            print(userhealth)

        else:
            slower_type("So you have choosen death")
            slower_type("GAME OVER")
            break
        ## add instant death while not open chest
        if openchest == "N":
            slower_type("I warned you")
           ## loop will diminish users health untill 0
           ## sys is used to print users heath in the same place
            while userhealth > 0:
                userhealth -= 1
                struserhealth = str(userhealth)
                sys.stdout.write("User Health:" +struserhealth+   " \r")
                sys.stdout.flush()
                time.sleep(0.05)
            ## Because users health was printing in place I added User Heal to clean the wording up
            print("User Heal")
            slower_type("GAME OVER")
            break

        ## boss attacks, user takes damage
        bam = random.randint(30,45)
        strbam = str(bam)
        for x in range(1,bam + 1):
            userhealth -= 1
            sys.stdout.write("User Health:" +str(userhealth)+" " +  "\r")
            sys.stdout.flush()
            time.sleep(0.05)
            if userhealth <= 0:
                slower_type(" You Died......GAME OVER")
                game_over = True
                break
        slow_type("\n Boss Damage drawn: "+ strbam)
        if userhealth <= 0:
            sys.exit()
        #   break
            slower_type("Congragulations...")
            slower_type("You have finally beaten Franz Gigalance")
            slower_type("Now you have one last choice to make...")
            slower_type("You can either give the gem back to the village")
            slower_type("or...")
            slow_type("Keep it for your self")
            final_option = input("(G or K):: ")
            if final_option == "G":
                slower_type("Congragulations...")
                slower_type("You have gotten the achievement...")
                slower_type("The HERO")
                slower_type("The village is flourishing again because of you")
                slower_type("Thanks for playing...")
            if final_option == "K":
                slower_type("Oh .... here we go again...")


main()

# %%
import sys,time,random
game_over = False
typing_speed = 50 #wpm
from os import system

## My Functions

## Slow type makes it so that when something is printed, it prints it out letter by letter
def slow_type(t):
    for l in t:
        sys.stdout.write(l)
        sys.stdout.flush()
        time.sleep(random.random()*5/typing_speed)
    print ('')

## Slower type makes it so that when something is printed, it prints it out letter by letter but even slower
##
## https://stackoverflow.com/questions/39422027/slow-printing-still-need-answers

def slower_type(t):
    for l in t:
        ## flush makes countdown countdown in place and write prints it
        sys.stdout.write(l)
        sys.stdout.flush()

        ## sleep tells computer to not do anything for a certain amount of time 
        time.sleep(random.random()*20/typing_speed)
    print ('')

## Build my porgram
def main():
    done = False
    while not done:
        print("Menu")
        print("G - Game")
        print("C - Clear Screen")
        print("Q - Quit")
        choice = input("Choice: ")
        if choice == "G":
            game()

        elif choice == "C":
            system('clear')

        elif choice == "Q":
            print("Exiting!")
            done = True

def game():


## items are set to shwo what is going to be used in the story
## enemy health and user health are set to their variables
    items = ["sword(s) = $50","food packages(f) = $30","map(m) = $20"]
    enemyhealth = 2000
    userhealth = 100

    ## Ive added a random function that puts a random swords into backpack
    backpack = []
    bossreactions = ["OOF","That was nothing","Not bad","..."]
    swords = ["Heavy Sword, ","Light Sword "]

    print("Starting game...")
    print("Welcome")
    print("to")

    ## User enters name
    nog = input("What should the name of the character be called: ")

    ## Secret printouts if user enters correct secret name
    if nog == "Beanos":
        slow_type("you drafted a theme from spongebob, nice")
    elif nog == "Shrek":
        slow_type("Shrek is love, Shrek is life")
        slow_type("( ͡° ͜ʖ °)")
    elif nog == "Waluigi":
        print(nog,"is not in smash")
    elif nog == "Shaggy":
        print(nog,"is in his final form")
    print("The Adventures of",nog)
    slow_type("Loading...")
    slow_type("....")
    slow_type("You start on a hilly mountain with a bunch of trees around you.")

    ## Ask user to move forward or back:
    move1 = input("What would you like to do next move(forward or backward): ")
    if move1 == "backward":

        ##storyline dialgoue
        slow_type("You start to walk toward the edge of the mountain and you realize you are standing on a cliff")
        slow_type("You decide to go to the left because")
        slow_type("You see a small building in the distance")
        slow_type("The building has a busted up sign on it that reads")
        slow_type("Free Stuff")

        ## ask user if he wants to go in to buy map
        building = input("Would you like to go inside the building(Y or N): ")
        if building == "N":
            print("")
        elif building == "Y":
            slow_type("You go inside of the building and see a shop clerk")
            slow_type("The shop clerk asks you")
            buym = input("Would you like to buy a map(Y or N): ")
            if buym == "Y":
                backpack.append("Map")
                items.remove("map(m) = $20")
                print(backpack)
                slow_type("You have a map")
                backpack.remove("Map")
            if buym == "N":
                print("")
        slow_type("You continue on your adventure")

    elif move1 == "forward":
        print("")

    ## user dies for not following directions
    else:
        slow_type("I told you to enter backward or forward, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()


    ##storyline dialgoue
    slow_type("You slide down the mountain and stumble upon a village")
    slow_type("You go to the village and see a ghost town that looks run down.")
    slow_type("As you start to walk toward the village")
    slow_type("A villager runs up to you and says")
    slow_type("Dont go there its too dangerous")
    slow_type("You continue on toward the village and see that every building is destroyed except for 1")
    slow_type("You walk up to the building and knock on the door.")
    slow_type("A villager come out and says")
    slow_type("Hurry come in, theyll get you")

    ## ask user to go inside. if he says no he dies
    insideb = input("Do you go inside yes or no: ")
    if insideb == "no":
        print("You start to walk back when you get struck in the head and sent to a river,you died")
        slower_type("Game over.....")
        sys.exit()

    elif insideb == "yes":
        ##storyline dialgoue
        slow_type("So you hurry on inside")
        slow_type("As soon as you went in, you realize that this building is a lot bigger on the inside than the outside")
        slow_type("The villager said")
        print("Hello",nog,"finally you have come to rescue us")
        print(nog,"says, how do you know my name, and what am reacuing you guys from?")
        slow_type("You are rescuing us from Franz Gigalance, you didn't know?")
        slow_type("He took our power gem and now the village is destroying itself.")
        slow_type("Ive heard that he is taking the gem to The Naguakate Volcano.")
        print(nog,"says")
        slow_type("How am I suposed to help, I dont even know where that is.")
        slow_type("I know you dont but I do, here let me show you")
        slow_type("🏠------------------🌊")
        slow_type("                    |")
        slow_type("                    |")
        slow_type("                    🌋")
        print(nog,",just follow the path and it shall take you there, goodluck")
        slow_type("You leave the building stealthy and quickly go strait.")
        slow_type("You realize that you dont have any gear with you.")

        ## ask user if he wants to go back, if yes he dies
        backg = input("Would you like to go back (Y or N): ")
        if backg == "Y":
            slow_type("You start to go back and notice something following you")
            slow_type("You try to continue back but your mauled by a bear ")
            slower_type("Game over.....")
            sys.exit()
        elif backg == "N":
            slow_type("You keep going on the path")
            slow_type("As you were walking you see a river")
            slow_type("By the river, you see a chest")

            ## ask user to open chest: He will be randomly assigned sword
            openchest = input("Would you like to open the chest(Y or N): ")
            if openchest == "Y":
                backpack.append(random.choice(swords))
                backpack.append("Food")
                slow_type("You have")
                slow_type(backpack)
            elif openchest == "N":
                slower_type("You will regret that...")

        ##storyline dialgoue
        slow_type("You continue on and see the enormous volcano in the distance.")
        slow_type("You can see small sparks coming from the volcano")
        slow_type("As you continue on you see a large bridge that is over a rapid river.")
        slower_type("...")
        slower_type("....")
        slow_type("..........................")
        print("( ͡°( ͡° ͜ʖ ͡°( ͡❛ ͜ʖ͡❛ ) ͡° ͜ʖ ͡°) ͡°)")
        print("Hello",nog)
        slow_type("Finally you have come")
        slow_type("Now we shall fight")
        slow_type("You stand no match for my men")

        ## build lists to determine if attack is superattack
        attack_list = ["Attack"] * 90
        sattack_list = ["Super Attack"] * 1
        sa_list = attack_list + sattack_list

        ## randomly pick attack/superattack
        if random.choice(sa_list).startswith("S"):
            smessage = True
        else:
            smessage = False

        ## h sword does more damage
        if "Heavy Sword, " in backpack:
            if random.choice(sa_list).startswith("S"):
                smessage = True
            dam = random.randint(65,75)

        ## light sword does less
        elif "Light Sword " in backpack:
            dam = random.randint(35,55)
        else: print(" you have no sword to attack with")
        f = False

      ## user dies for not following directions
    else:
        slow_type("I told you to enter yes or no, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()

    ## boss battle: ends if boss or player health falls below 0
    while enemyhealth > 0:
        if random.choice(sa_list).startswith("S"):
            smessage = True
        if smessage == True:
            print("SA - Super Attack")
            print("H - Heal")
            ## made it so lower case dosen't insta kill
            u_input = input(":: ").upper()
            if u_input == "SA":
                print(random.choice(bossreactions))
                sdam = 2000
                strdam = str(sdam)
                enemyhealth -= sdam
                print(enemyhealth)
                slow_type("Damage drawn: "+ strdam)
                break
            elif u_input == "H":
                userhealth += 40
                print(userhealth)

        ## not super attack
        print("A - Attack")
        print("H - Heal")
        ## made it so lower case dosen't insta kill
        u_input = input(":: ").upper()
        if u_input == "A":
            print(random.choice(bossreactions))
            if "Heavy Sword, " in backpack:
                dam = random.randint(65,75)
            ## light sword does less
            elif "Light Sword " in backpack:
                dam = random.randint(35,55)
            strdam = str(dam)
            enemyhealth -= dam
            print(enemyhealth)
            slow_type("Damage drawn: "+ strdam)
        elif u_input == "H":
            userhealth += 40
            print(userhealth)

        else:
            slower_type("So you have choosen death")
            slower_type("GAME OVER")
            break
        ## add instant death while not open chest
        if openchest == "N":
            slower_type("I warned you")
           ## loop will diminish users health untill 0
           ## sys is used to print users heath in the same place
            while userhealth > 0:
                userhealth -= 1
                struserhealth = str(userhealth)
                sys.stdout.write("User Health:" +struserhealth+   " \r")
                sys.stdout.flush()
                time.sleep(0.05)
            ## Because users health was printing in place I added User Heal to clean the wording up
            print("User Heal")
            slower_type("GAME OVER")
            break

        ## boss attacks, user takes damage
        bam = random.randint(30,45)
        strbam = str(bam)
        for x in range(1,bam + 1):
            userhealth -= 1
            sys.stdout.write("User Health:" +str(userhealth)+" " +  "\r")
            sys.stdout.flush()
            time.sleep(0.05)
            if userhealth <= 0:
                slower_type(" You Died......GAME OVER")
                game_over = True
                break
        slow_type("\n Boss Damage drawn: "+ strbam)
        if userhealth <= 0:
            sys.exit()
        #   break
            slower_type("Congragulations...")
            slower_type("You have finally beaten Franz Gigalance")
            slower_type("Now you have one last choice to make...")
            slower_type("You can either give the gem back to the village")
            slower_type("or...")
            slow_type("Keep it for your self")
            final_option = input("(G or K):: ")
            if final_option == "G":
                slower_type("Congragulations...")
                slower_type("You have gotten the achievement...")
                slower_type("The HERO")
                slower_type("The village is flourishing again because of you")
                slower_type("Thanks for playing...")
            if final_option == "K":
                slower_type("Oh .... here we go again...")


main()

# %%
import sys,time,random
game_over = False
typing_speed = 50 #wpm
from os import system

## My Functions

## Slow type makes it so that when something is printed, it prints it out letter by letter
def slow_type(t):
    for l in t:
        sys.stdout.write(l)
        sys.stdout.flush()
        time.sleep(random.random()*5/typing_speed)
    print ('')

## Slower type makes it so that when something is printed, it prints it out letter by letter but even slower
##
## https://stackoverflow.com/questions/39422027/slow-printing-still-need-answers

def slower_type(t):
    for l in t:
        ## flush makes countdown countdown in place and write prints it
        sys.stdout.write(l)
        sys.stdout.flush()

        ## sleep tells computer to not do anything for a certain amount of time
        time.sleep(random.random()*20/typing_speed)
    print ('')

## Build my porgram
def main():
    done = False
    while not done:
        print("Menu")
        print("G - Game")
        print("C - Clear Screen")
        print("Q - Quit")
        choice = input("Choice: ")
        if choice == "G":
            game()

        elif choice == "C":
            system('clear')

        elif choice == "Q":
            print("Exiting!")
            done = True

def game():


## items are set to shwo what is going to be used in the story
## enemy health and user health are set to their variables
    items = ["sword(s) = $50","food packages(f) = $30","map(m) = $20"]
    enemyhealth = 2000
    userhealth = 100

    ## Ive added a random function that puts a random swords into backpack
    backpack = []
    bossreactions = ["OOF","That was nothing","Not bad","..."]
    swords = ["Heavy Sword, ","Light Sword "]

    print("Starting game...")
    print("Welcome")
    print("to")

    ## User enters name
    nog = input("What should the name of the character be called: ")

    ## Secret printouts if user enters correct secret name
    if nog == "Beanos":
        slow_type("you drafted a theme from spongebob, nice")
    elif nog == "Shrek":
        slow_type("Shrek is love, Shrek is life")
        slow_type("( ͡° ͜ʖ °)")
    elif nog == "Waluigi":
        print(nog,"is not in smash")
    elif nog == "Shaggy":
        print(nog,"is in his final form")
    print("The Adventures of",nog)
    slow_type("Loading...")
    slow_type("....")
    slow_type("You start on a hilly mountain with a bunch of trees around you.")

    ## Ask user to move forward or back:
    move1 = input("What would you like to do next move(forward or backward): ")
    if move1 == "backward":

        ##storyline dialgoue
        slow_type("You start to walk toward the edge of the mountain and you realize you are standing on a cliff")
        slow_type("You decide to go to the left because")
        slow_type("You see a small building in the distance")
        slow_type("The building has a busted up sign on it that reads")
        slow_type("Free Stuff")

        ## ask user if he wants to go in to buy map
        building = input("Would you like to go inside the building(Y or N): ")
        if building == "N":
            print("")
        elif building == "Y":
            slow_type("You go inside of the building and see a shop clerk")
            slow_type("The shop clerk asks you")
            buym = input("Would you like to buy a map(Y or N): ")
            if buym == "Y":
                backpack.append("Map")
                items.remove("map(m) = $20")
                print(backpack)
                slow_type("You have a map")
                backpack.remove("Map")
            if buym == "N":
                print("")
        slow_type("You continue on your adventure")

    elif move1 == "forward":
        print("")

    ## user dies for not following directions
    else:
        slow_type("I told you to enter backward or forward, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()


    ##storyline dialgoue
    slow_type("You slide down the mountain and stumble upon a village")
    slow_type("You go to the village and see a ghost town that looks run down.")
    slow_type("As you start to walk toward the village")
    slow_type("A villager runs up to you and says")
    slow_type("Dont go there its too dangerous")
    slow_type("You continue on toward the village and see that every building is destroyed except for 1")
    slow_type("You walk up to the building and knock on the door.")
    slow_type("A villager come out and says")
    slow_type("Hurry come in, theyll get you")

    ## ask user to go inside. if he says no he dies
    insideb = input("Do you go inside yes or no: ")
    if insideb == "no":
        print("You start to walk back when you get struck in the head and sent to a river,you died")
        slower_type("Game over.....")
        sys.exit()

    elif insideb == "yes":
        ##storyline dialgoue
        slow_type("So you hurry on inside")
        slow_type("As soon as you went in, you realize that this building is a lot bigger on the inside than the outside")
        slow_type("The villager said")
        print("Hello",nog,"finally you have come to rescue us")
        print(nog,"says, how do you know my name, and what am reacuing you guys from?")
        slow_type("You are rescuing us from Franz Gigalance, you didn't know?")
        slow_type("He took our power gem and now the village is destroying itself.")
        slow_type("Ive heard that he is taking the gem to The Naguakate Volcano.")
        print(nog,"says")
        slow_type("How am I suposed to help, I dont even know where that is.")
        slow_type("I know you dont but I do, here let me show you")
        slow_type("🏠------------------🌊")
        slow_type("                    |")
        slow_type("                    |")
        slow_type("                    🌋")
        print(nog,",just follow the path and it shall take you there, goodluck")
        slow_type("You leave the building stealthy and quickly go strait.")
        slow_type("You realize that you dont have any gear with you.")

        ## ask user if he wants to go back, if yes he dies
        backg = input("Would you like to go back (Y or N): ")
        if backg == "Y":
            slow_type("You start to go back and notice something following you")
            slow_type("You try to continue back but your mauled by a bear ")
            slower_type("Game over.....")
            sys.exit()
        elif backg == "N":
            slow_type("You keep going on the path")
            slow_type("As you were walking you see a river")
            slow_type("By the river, you see a chest")

            ## ask user to open chest: He will be randomly assigned sword
            openchest = input("Would you like to open the chest(Y or N): ")
            if openchest == "Y":
                backpack.append(random.choice(swords))
                backpack.append("Food")
                slow_type("You have")
                slow_type(backpack)
            elif openchest == "N":
                slower_type("You will regret that...")

        ##storyline dialgoue
        slow_type("You continue on and see the enormous volcano in the distance.")
        slow_type("You can see small sparks coming from the volcano")
        slow_type("As you continue on you see a large bridge that is over a rapid river.")
        slower_type("...")
        slower_type("....")
        slow_type("..........................")
        print("( ͡°( ͡° ͜ʖ ͡°( ͡❛ ͜ʖ͡❛ ) ͡° ͜ʖ ͡°) ͡°)")
        print("Hello",nog)
        slow_type("Finally you have come")
        slow_type("Now we shall fight")
        slow_type("You stand no match for my men")

        ## build lists to determine if attack is superattack
        attack_list = ["Attack"] * 90
        sattack_list = ["Super Attack"] * 1
        sa_list = attack_list + sattack_list

        ## randomly pick attack/superattack
        if random.choice(sa_list).startswith("S"):
            smessage = True
        else:
            smessage = False

        ## h sword does more damage
        if "Heavy Sword, " in backpack:
            if random.choice(sa_list).startswith("S"):
                smessage = True
            dam = random.randint(200,250)

        ## light sword does less
        elif "Light Sword " in backpack:
            dam = random.randint(150,175)
        else: print(" you have no sword to attack with")
        f = False

      ## user dies for not following directions
    else:
        slow_type("I told you to enter yes or no, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()

    ## boss battle: ends if boss or player health falls below 0
    while enemyhealth > 0:
        if random.choice(sa_list).startswith("S"):
            smessage = True
        if smessage == True:
            print("SA - Super Attack")
            print("H - Heal")
            ## made it so lower case dosen't insta kill
            u_input = input(":: ").upper()
            if u_input == "SA":
                print(random.choice(bossreactions))
                sdam = 2000
                strdam = str(sdam)
                enemyhealth -= sdam
                print(enemyhealth)
                slow_type("Damage drawn: "+ strdam)
                break
            elif u_input == "H":
                userhealth += 40
                print(userhealth)

        ## not super attack
        print("A - Attack")
        print("H - Heal")
        ## made it so lower case dosen't insta kill
        u_input = input(":: ").upper()
        if u_input == "A":
            print(random.choice(bossreactions))
            if "Heavy Sword, " in backpack:
                dam = random.randint(200,250)
            ## light sword does less
            elif "Light Sword " in backpack:
                dam = random.randint(150,200)
            strdam = str(dam)
            for x in range(1,dam + 1):
                enemyhealth -= 1
                sys.stdout.write("User Health:" +str(userhealth)+" " +  "\r")
                sys.stdout.flush()
                time.sleep(0.05)
            slow_type("Damage drawn: "+ strdam)
        elif u_input == "H":
            userhealth += 40
            print(userhealth)

        else:
            slower_type("So you have choosen death")
            slower_type("GAME OVER")
            break
        ## add instant death while not open chest
        if openchest == "N":
            slower_type("I warned you")
           ## loop will diminish users health untill 0
           ## sys is used to print users heath in the same place
            while userhealth > 0:
                userhealth -= 1
                struserhealth = str(userhealth)
                sys.stdout.write("User Health:" +struserhealth+   " \r")
                sys.stdout.flush()
                time.sleep(0.05)
            ## Because users health was printing in place I added User Heal to clean the wording up
            print("User Heal")
            slower_type("GAME OVER")
            break

        ## boss attacks, user takes damage
        bam = random.randint(30,45)
        strbam = str(bam)
        for x in range(1,bam + 1):
            userhealth -= 1
            sys.stdout.write("User Health:" +str(userhealth)+" " +  "\r")
            sys.stdout.flush()
            time.sleep(0.05)
            if userhealth <= 0:
                slower_type(" You Died......GAME OVER")
                game_over = True
                break
        slow_type("\n Boss Damage drawn: "+ strbam)
        if userhealth <= 0:
            sys.exit()

    ## user won game 
    slower_type("Congragulations...")
    slower_type("You have finally beaten Franz Gigalance")
    slower_type("Now you have one last choice to make...")
    slower_type("You can either give the gem back to the village")
    slower_type("or...")
    slow_type("Keep it for your self")
    final_option = input("(G or K):: ")
    if final_option == "G":
        slower_type("Congragulations...")
        slower_type("You have gotten the achievement...")
        slower_type("The HERO")
        slower_type("The village is flourishing again because of you")
        slower_type("Thanks for playing...")
    if final_option == "K":
        slower_type("Oh .... here we go again...")


main()

# %%
import sys,time,random
game_over = False
typing_speed = 25000 #wpm
from os import system

## My Functions

## Slow type makes it so that when something is printed, it prints it out letter by letter
def slow_type(t):
    for l in t:
        sys.stdout.write(l)
        sys.stdout.flush()
        time.sleep(random.random()*5/typing_speed)
    print ('')

## Slower type makes it so that when something is printed, it prints it out letter by letter but even slower
##
## https://stackoverflow.com/questions/39422027/slow-printing-still-need-answers

def slower_type(t):
    for l in t:
        ## flush makes countdown countdown in place and write prints it
        sys.stdout.write(l)
        sys.stdout.flush()

        ## sleep tells computer to not do anything for a certain amount of time
        time.sleep(random.random()*20/typing_speed)
    print ('')

## Build my porgram
def main():
    done = False
    while not done:
        print("Menu")
        print("G - Game")
        print("C - Clear Screen")
        print("Q - Quit")
        choice = input("Choice: ")
        if choice == "G":
            game()

        elif choice == "C":
            system('clear')

        elif choice == "Q":
            print("Exiting!")
            done = True

def game():


## items are set to shwo what is going to be used in the story
## enemy health and user health are set to their variables
    items = ["sword(s) = $50","food packages(f) = $30","map(m) = $20"]
    enemyhealth = 2000
    userhealth = 100

    ## Ive added a random function that puts a random swords into backpack
    backpack = []
    bossreactions = ["OOF","That was nothing","Not bad","..."]
    swords = ["Heavy Sword, ","Light Sword "]

    print("Starting game...")
    print("Welcome")
    print("to")

    ## User enters name
    nog = input("What should the name of the character be called: ")

    ## Secret printouts if user enters correct secret name
    if nog == "Beanos":
        slow_type("you drafted a theme from spongebob, nice")
    elif nog == "Shrek":
        slow_type("Shrek is love, Shrek is life")
        slow_type("( ͡° ͜ʖ °)")
    elif nog == "Waluigi":
        print(nog,"is not in smash")
    elif nog == "Shaggy":
        print(nog,"is in his final form")
    print("The Adventures of",nog)
    slow_type("Loading...")
    slow_type("....")
    slow_type("You start on a hilly mountain with a bunch of trees around you.")

    ## Ask user to move forward or back:
    move1 = input("What would you like to do next move(forward or backward): ")
    if move1 == "backward":

        ##storyline dialgoue
        slow_type("You start to walk toward the edge of the mountain and you realize you are standing on a cliff")
        slow_type("You decide to go to the left because")
        slow_type("You see a small building in the distance")
        slow_type("The building has a busted up sign on it that reads")
        slow_type("Free Stuff")

        ## ask user if he wants to go in to buy map
        building = input("Would you like to go inside the building(Y or N): ")
        if building == "N":
            print("")
        elif building == "Y":
            slow_type("You go inside of the building and see a shop clerk")
            slow_type("The shop clerk asks you")
            buym = input("Would you like to buy a map(Y or N): ")
            if buym == "Y":
                backpack.append("Map")
                items.remove("map(m) = $20")
                print(backpack)
                slow_type("You have a map")
                backpack.remove("Map")
            if buym == "N":
                print("")
        slow_type("You continue on your adventure")

    elif move1 == "forward":
        print("")

    ## user dies for not following directions
    else:
        slow_type("I told you to enter backward or forward, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()


    ##storyline dialgoue
    slow_type("You slide down the mountain and stumble upon a village")
    slow_type("You go to the village and see a ghost town that looks run down.")
    slow_type("As you start to walk toward the village")
    slow_type("A villager runs up to you and says")
    slow_type("Dont go there its too dangerous")
    slow_type("You continue on toward the village and see that every building is destroyed except for 1")
    slow_type("You walk up to the building and knock on the door.")
    slow_type("A villager come out and says")
    slow_type("Hurry come in, theyll get you")

    ## ask user to go inside. if he says no he dies
    insideb = input("Do you go inside yes or no: ")
    if insideb == "no":
        print("You start to walk back when you get struck in the head and sent to a river,you died")
        slower_type("Game over.....")
        sys.exit()

    elif insideb == "yes":
        ##storyline dialgoue
        slow_type("So you hurry on inside")
        slow_type("As soon as you went in, you realize that this building is a lot bigger on the inside than the outside")
        slow_type("The villager said")
        print("Hello",nog,"finally you have come to rescue us")
        print(nog,"says, how do you know my name, and what am reacuing you guys from?")
        slow_type("You are rescuing us from Franz Gigalance, you didn't know?")
        slow_type("He took our power gem and now the village is destroying itself.")
        slow_type("Ive heard that he is taking the gem to The Naguakate Volcano.")
        print(nog,"says")
        slow_type("How am I suposed to help, I dont even know where that is.")
        slow_type("I know you dont but I do, here let me show you")
        slow_type("🏠------------------🌊")
        slow_type("                    |")
        slow_type("                    |")
        slow_type("                    🌋")
        print(nog,",just follow the path and it shall take you there, goodluck")
        slow_type("You leave the building stealthy and quickly go strait.")
        slow_type("You realize that you dont have any gear with you.")

        ## ask user if he wants to go back, if yes he dies
        backg = input("Would you like to go back (Y or N): ")
        if backg == "Y":
            slow_type("You start to go back and notice something following you")
            slow_type("You try to continue back but your mauled by a bear ")
            slower_type("Game over.....")
            sys.exit()
        elif backg == "N":
            slow_type("You keep going on the path")
            slow_type("As you were walking you see a river")
            slow_type("By the river, you see a chest")

            ## ask user to open chest: He will be randomly assigned sword
            openchest = input("Would you like to open the chest(Y or N): ")
            if openchest == "Y":
                backpack.append(random.choice(swords))
                backpack.append("Food")
                slow_type("You have")
                slow_type(backpack)
            elif openchest == "N":
                slower_type("You will regret that...")

        ##storyline dialgoue
        slow_type("You continue on and see the enormous volcano in the distance.")
        slow_type("You can see small sparks coming from the volcano")
        slow_type("As you continue on you see a large bridge that is over a rapid river.")
        slower_type("...")
        slower_type("....")
        slow_type("..........................")
        print("( ͡°( ͡° ͜ʖ ͡°( ͡❛ ͜ʖ͡❛ ) ͡° ͜ʖ ͡°) ͡°)")
        print("Hello",nog)
        slow_type("Finally you have come")
        slow_type("Now we shall fight")
        slow_type("You stand no match for my men")

        ## build lists to determine if attack is superattack
        attack_list = ["Attack"] * 90
        sattack_list = ["Super Attack"] * 1
        sa_list = attack_list + sattack_list

        ## randomly pick attack/superattack
        if random.choice(sa_list).startswith("S"):
            smessage = True
        else:
            smessage = False

        ## h sword does more damage
        if "Heavy Sword, " in backpack:
            if random.choice(sa_list).startswith("S"):
                smessage = True
            dam = random.randint(200,250)

        ## light sword does less
        elif "Light Sword " in backpack:
            dam = random.randint(150,175)
        else: print(" you have no sword to attack with")
        f = False

      ## user dies for not following directions
    else:
        slow_type("I told you to enter yes or no, you should have listened.  Maybe you will listen next time ....game over")
        sys.exit()

    ## boss battle: ends if boss or player health falls below 0
    while enemyhealth > 0:
        if random.choice(sa_list).startswith("S"):
            smessage = True
        if smessage == True:
            print("SA - Super Attack")
            print("H - Heal")
            ## made it so lower case dosen't insta kill
            u_input = input(":: ").upper()
            if u_input == "SA":
                print(random.choice(bossreactions))
                sdam = 2000
                strdam = str(sdam)
                enemyhealth -= sdam
                print(enemyhealth)
                slow_type("Damage drawn: "+ strdam)
                break
            elif u_input == "H":
                userhealth += 40
                print(userhealth)

        ## not super attack
        print("A - Attack")
        print("H - Heal")
        ## made it so lower case dosen't insta kill
        u_input = input(":: ").upper()
        if u_input == "A":
            print(random.choice(bossreactions))
            if "Heavy Sword, " in backpack:
                dam = random.randint(200,250)
            ## light sword does less
            elif "Light Sword " in backpack:
                dam = random.randint(150,200)
            strdam = str(dam)
            for x in range(1,dam + 1):
                enemyhealth -= 1
                sys.stdout.write(" Boss Health:" +str(enemyhealth)+" " +  "\r")
                sys.stdout.flush()
                time.sleep(0.05)
            slow_type("\n Damage drawn: "+ strdam)
        elif u_input == "H":
            userhealth += 40
            print(userhealth)

        else:
            slower_type("So you have choosen death")
            slower_type("GAME OVER")
            break
        ## add instant death while not open chest
        if openchest == "N":
            slower_type("I warned you")
           ## loop will diminish users health untill 0
           ## sys is used to print users heath in the same place
            while userhealth > 0:
                userhealth -= 1
                struserhealth = str(userhealth)
                sys.stdout.write("User Health:" +struserhealth+   " \r")
                sys.stdout.flush()
                time.sleep(0.05)
            ## Because users health was printing in place I added User Heal to clean the wording up
            print("User Heal")
            slower_type("GAME OVER")
            break

        ## boss attacks, user takes damage
        bam = random.randint(30,45)
        strbam = str(bam)
        for x in range(1,bam + 1):
            userhealth -= 1
            sys.stdout.write("User Health:" +str(userhealth)+" " +  "\r")
            sys.stdout.flush()
            time.sleep(0.05)
            if userhealth <= 0:
                slower_type(" You Died......GAME OVER")
                game_over = True
                break
        slow_type("\n Boss Damage drawn: "+ strbam)
        if userhealth <= 0:
            sys.exit()

    ## user won game
    slow_type("You have finally beaten Franz Gigalance")
    slow_type("Now you have one last choice to make...")
    slow_type("You can either give the gem back to the village")
    slow_type("or...")
    slow_type("Keep it for your self")
    final_option = input("(G or K):: ")
    if final_option == "G":
        slow_type("Congragulations...")
        slow_type("You have gotten the achievement...")
        slow_type("The HERO")
        slow_type("The village is flourishing again because of you")
        slow_type("Thanks for playing...")
    if final_option == "K":
        slow_type("Oh .... here we go again...")


main()
# Out:
# Menu
# G - Game
# C - Clear Screen
# Q - Quit
# Choice: G
# Starting game...
# Welcome
# to
# What should the name of the character be called: h
# The Adventures of h
# Loading...
# ....
# You start on a hilly mountain with a bunch of trees around you.
# What would you like to do next move(forward or backward): forward
#
# You slide down the mountain and stumble upon a village
# You go to the village and see a ghost town that looks run down.
# As you start to walk toward the village
# A villager runs up to you and says
# Dont go there its too dangerous
# You continue on toward the village and see that every building is destroyed except for 1
# You walk up to the building and knock on the door.
# A villager come out and says
# Hurry come in, theyll get you
# Do you go inside yes or no: yes
# So you hurry on inside
# As soon as you went in, you realize that this building is a lot bigger on the inside than the outside
# The villager said
# Hello h finally you have come to rescue us
# ...
